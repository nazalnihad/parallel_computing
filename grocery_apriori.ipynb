# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import warnings
warnings.filterwarnings("ignore")

# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
#   inflating: Groceries_dataset.csv

# %%
# !pwd
# Out:
# /content

# %%
df = pd.read_csv('/content/Groceries_dataset.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <ipython-input-10-b9c6864122be>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dropna()
# Out:
#        Member_number       Date        itemDescription          invoice
# 0               1808 2015-07-21         tropical fruit  1808_2015-07-21
# 1               2552 2015-01-05             whole milk  2552_2015-01-05
# 2               2300 2015-09-19              pip fruit  2300_2015-09-19
# 3               1187 2015-12-12       other vegetables  1187_2015-12-12
# 4               3037 2015-02-01             whole milk  3037_2015-02-01
# ...              ...        ...                    ...              ...
# 38760           4471 2014-10-08          sliced cheese  4471_2014-10-08
# 38761           2022 2014-02-23                  candy  2022_2014-02-23
# 38762           1097 2014-04-16               cake bar  1097_2014-04-16
# 38763           1510 2014-12-03  fruit/vegetable juice  1510_2014-12-03
# 38764           1521 2014-12-26               cat food  1521_2014-12-26
#
# [38765 rows x 4 columns]

# %%
df["invoice"] = df['Member_number'].astype(str) + '_' + df["Date"].astype(str)
new_df = pd.pivot_table(df, index='invoice', columns='itemDescription', values='Member_number')

# %%
new_df
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# invoice
# 1000_2014-06-24                      0         0                 0
# 1000_2015-03-15                      0         0                 0
# 1000_2015-05-27                      0         0                 0
# 1000_2015-07-24                      0         0                 0
# 1000_2015-11-25                      0         0                 0
# ...                                ...       ...               ...
# 4999_2015-05-16                      0         0                 0
# 4999_2015-12-26                      0         0                 0
# 5000_2014-03-09                      0         0                 0
# 5000_2014-11-16                      0         0                 0
# 5000_2015-02-10                      0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# invoice
# ...

# %%
0 in df['Member_number']


new_df = new_df +1
new_df = new_df.fillna(0)
new_df = new_df.applymap(lambda x: 1 if x!= 0 else 0)
# Out:
# <ipython-input-25-1f8f9e7eae21>:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   new_df = new_df.applymap(lambda x: 1 if x!= 0 else 0)

# %%
apriori_df = apriori(new_df,
                     min_support=0.005,
                     use_colnames=True,
                     low_memory=True)
rules = association_rules(apriori_df,
                          metric='support',
                          min_threshold=0.001)

# %%
sorted_rules = rules.sort_values('lift', ascending=False)
sorted_rules
# Out:
#            antecedents         consequents  antecedent support  \
# 13       (frankfurter)  (other vegetables)            0.037760
# 12  (other vegetables)       (frankfurter)            0.122101
# 59           (sausage)            (yogurt)            0.060349
# 58            (yogurt)           (sausage)            0.085879
# 54              (soda)           (sausage)            0.097106
# ..                 ...                 ...                 ...
# 67              (soda)            (yogurt)            0.097106
# 52   (root vegetables)        (whole milk)            0.069572
# 53        (whole milk)   (root vegetables)            0.157923
# 21  (other vegetables)   (root vegetables)            0.122101
# 20   (root vegetables)  (other vegetables)            0.069572
#
#     consequent support   support  confidence      lift  representativity  \
# 13            0.122101  0.005146    0.136283  1.116150               1.0
# ...

# %%
sorted_rules.describe()
# Out:
#        antecedent support  consequent support    support  confidence  \
# count           74.000000           74.000000  74.000000   74.000000
# mean             0.100394            0.100394   0.007229    0.082724
# std              0.040823            0.040823   0.002439    0.034744
# min              0.037091            0.037091   0.005012    0.031739
# 25%              0.067767            0.067767   0.005480    0.052101
# 50%              0.097106            0.097106   0.006282    0.078144
# 75%              0.122101            0.122101   0.008087    0.106360
# max              0.157923            0.157923   0.014837    0.157817
#
#             lift  representativity   leverage  conviction  zhangs_metric  \
# count  74.000000              74.0  74.000000   74.000000      74.000000
# mean    0.830099               1.0  -0.001661    0.980537      -0.185650
# std     0.103803               0.0   0.001168    0.014098       0.110415
# ...

# %%
filtered_rules = sorted_rules[sorted_rules['support'] > 0.01]

sorted_filtered_rules = filtered_rules.sort_values('support', ascending=False)

for index, row in sorted_filtered_rules.iterrows():
    print(f"Rule: {row['antecedents']} -> {row['consequents']}")
    print(f"Support: {row['support']:.4f}")
    print(f"Confidence: {row['confidence']:.4f}")
    print(f"Lift: {row['lift']:.4f}")
    print("---")
# Out:
# Rule: frozenset({'other vegetables'}) -> frozenset({'whole milk'})
# Support: 0.0148
# Confidence: 0.1215
# Lift: 0.7694
# ---
# Rule: frozenset({'whole milk'}) -> frozenset({'other vegetables'})
# Support: 0.0148
# Confidence: 0.0939
# Lift: 0.7694
# ---
# Rule: frozenset({'whole milk'}) -> frozenset({'rolls/buns'})
# Support: 0.0140
# Confidence: 0.0884
# Lift: 0.8040
# ---
# Rule: frozenset({'rolls/buns'}) -> frozenset({'whole milk'})
# Support: 0.0140
# Confidence: 0.1270
# Lift: 0.8040
# ---
# Rule: frozenset({'whole milk'}) -> frozenset({'soda'})
# Support: 0.0116
# Confidence: 0.0736
# Lift: 0.7583
# ---
# Rule: frozenset({'soda'}) -> frozenset({'whole milk'})
# Support: 0.0116
# Confidence: 0.1198
# Lift: 0.7583
# ---
# Rule: frozenset({'whole milk'}) -> frozenset({'yogurt'})
# Support: 0.0112
# Confidence: 0.0707
# Lift: 0.8229
# ---
# Rule: frozenset({'yogurt'}) -> frozenset({'whole milk'})
# Support: 0.0112
# Confidence: 0.1300
# Lift: 0.8229
# ---
# ...

# %%
def calculate_support(df, item):
    total_transactions = df['invoice'].nunique()
    item_transactions = df[df['itemDescription'] == item]['invoice'].nunique()
    return item_transactions / total_transactions

print(calculate_support(df, 'whole milk'))
# Out:
# 0.15792287642852368

# %%
for threshold in [0.01, 0.005, 0.001]:
    frequent_itemsets = apriori(new_df, min_support=threshold, use_colnames=True)
    print(f"Min support {threshold}: {len(frequent_itemsets)} itemsets")
# Out:
# Min support 0.01: 69 itemsets
# Min support 0.005: 126 itemsets
# Min support 0.001: 750 itemsets

# %%
df = pd.read_csv('/content/Groceries_dataset.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.dropna()

df["invoice"] = df['Member_number'].astype(str) + '_' + df["Date"].astype(str)
new_df = pd.pivot_table(df, index='invoice', columns='itemDescription', values='Member_number')

new_df = new_df +1
new_df = new_df.fillna(0)
new_df = new_df.applymap(lambda x: 1 if x!= 0 else 0)


apriori_df = apriori(new_df,
                     min_support=0.001,
                     use_colnames=True,
                     low_memory=True)
rules = association_rules(apriori_df,
                          metric='support',
                          min_threshold=0.001)

sorted_rules = rules.sort_values('lift', ascending=False)
sorted_rules

def calculate_support(df, item):
    total_transactions = df['invoice'].nunique()
    item_transactions = df[df['itemDescription'] == item]['invoice'].nunique()
    return item_transactions / total_transactions

print(calculate_support(df, 'whole milk'))
for threshold in [0.01, 0.005, 0.001]:
    frequent_itemsets = apriori(new_df, min_support=threshold, use_colnames=True)
    print(f"Min support {threshold}: {len(frequent_itemsets)} itemsets")

filtered_rules = sorted_rules[sorted_rules['support'] > 0.01]

sorted_filtered_rules = filtered_rules.sort_values('support', ascending=False)

for index, row in sorted_filtered_rules.iterrows():
    print(f"Rule: {row['antecedents']} -> {row['consequents']}")
    print(f"Support: {row['support']:.4f}")
    print(f"Confidence: {row['confidence']:.4f}")
    print(f"Lift: {row['lift']:.4f}")
    print("---")
